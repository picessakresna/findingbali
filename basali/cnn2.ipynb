# %% [markdown]
# ## About This Project

# %% [markdown]
# This project is focused on the detection of 'Aksara Bali' - a traditional Balinese script. The goal is to develop a machine learning model that can accurately identify different characters in the Aksara Bali script.
#
# The project involves several steps, including data collection, data preprocessing, model training, and model evaluation. The data consists of images of different Aksara Bali characters, which are stored in separate directories for each character.
#
# The model is built using TensorFlow, a popular machine learning library. It uses a Convolutional Neural Network (CNN), which is a type of deep learning model particularly effective for image classification tasks.
#
# The model's performance is evaluated based on its accuracy in predicting the correct Aksara Bali character from the images in the validation set. Various strategies, such as regularization and learning rate adjustment, are employed to optimize the model's performance and prevent overfitting.
#
# The project is a significant contribution to the preservation and digitization of traditional scripts, enabling more efficient and accurate recognition of Aksara Bali characters.

# %% [markdown]
# ### Preparation Files for Making Models

# %% [markdown]
# For prepare this project you can download the dataset from https://drive.google.com/drive/folders/1STj-TVq42OYVbbtfBHML00313Y0TKFTU?usp=drive_link

# %% [markdown]
# ### Preparation Models

# %%
import os
import shutil
import random
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %cd D:/SELF/ML/aksara-detection/code/findingbali/dataset
# Out:
# D:\SELF\ML\aksara-detection\code\findingbali\dataset

# %%
list_aksara = {
    0: 'adeg-adeg',
    1: 'ba',
    2: 'bisah',
    3: 'ca',
    4: 'cecek',
    5: 'da',
    6: 'delapan',
    7: 'dua',
    8: 'empat',
    9: 'enam',
    10: 'ga',
    11: 'gantungan ba',
    12: 'gantungan ca',
    13: 'gantungan da',
    14: 'gantungan ga',
    15: 'gantungan ha',
    16: 'gantungan ja',
    17: 'gantungan ka',
    18: 'gantungan la',
    19: 'gantungan ma',
    20: 'gantungan na',
    21: 'gantungan nga',
    22: 'gantungan nya',
    23: 'gantungan pa',
    24: 'gantungan ra',
    25: 'gantungan sa',
    26: 'gantungan ta',
    27: 'gantungan wa',
    28: 'gantungan ya',
    29: 'ha',
    30: 'ja',
    31: 'ka',
    32: 'la',
    33: 'lima',
    34: 'ma',
    35: 'na',
    36: 'nga',
    37: 'nya',
    38: 'pa',
    39: 'pepet',
    40: 'ra',
    41: 'sa',
    42: 'satu',
    43: 'sembilan',
    44: 'suku',
    45: 'surang',
    46: 'ta',
    47: 'taleng',
    48: 'taleng tedong',
    49: 'tedong',
    50: 'tiga',
    51: 'tujuh',
    52: 'ulu',
    53: 'wa',
    54: 'ya'
}

for key, value in list_aksara.items():
    source_path = f"D:/SELF/ML/aksara-detection/code/findingbali/dataset/{value}"
    if not os.path.exists(source_path):
        os.makedirs(source_path)
    print(f"There are {len(os.listdir(source_path))} images of {value}")
# Out:
# There are 99 images of adeg-adeg
# There are 93 images of ba
# There are 101 images of bisah
# There are 98 images of ca
# There are 97 images of cecek
# There are 95 images of da
# There are 95 images of delapan
# There are 91 images of dua
# There are 96 images of empat
# There are 101 images of enam
# There are 98 images of ga
# There are 76 images of gantungan ba
# There are 79 images of gantungan ca
# There are 71 images of gantungan da
# There are 73 images of gantungan ga
# There are 78 images of gantungan ha
# There are 72 images of gantungan ja
# There are 79 images of gantungan ka
# There are 75 images of gantungan la
# There are 75 images of gantungan ma
# There are 76 images of gantungan na
# There are 77 images of gantungan nga
# There are 72 images of gantungan nya
# There are 77 images of gantungan pa
# There are 75 images of gantungan ra
# There are 81 images of gantungan sa
# There are 77 images of gantungan ta
# There are 73 images of gantungan wa
# There are 74 images of gantungan ya
# There are 96 images of ha
# There are 108 images of ja
# There are 104 images of ka
# There are 98 images of la
# There are 100 images of lima
# There are 101 images of ma
# There are 109 images of na
# There are 101 images of nga
# There are 95 images of nya
# There are 99 images of pa
# There are 98 images of pepet
# There are 94 images of ra
# There are 97 images of sa
# There are 98 images of satu
# There are 100 images of sembilan
# There are 97 images of suku
# There are 101 images of surang
# There are 94 images of ta
# There are 101 images of taleng
# There are 102 images of taleng tedong
# There are 100 images of tedong
# There are 101 images of tiga
# There are 101 images of tujuh
# There are 99 images of ulu
# There are 100 images of wa
# There are 95 images of ya

# %%
TRAINING_DIR="D:/SELF/ML/aksara-detection/code/findingbali/dataset"
VALIDATION_DIR="D:/SELF/ML/aksara-detection/code/findingbali/dataset"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
    )

train_generator= train_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(150, 150),
    batch_size=40,
    class_mode='categorical',
    subset='training')

num_train_data = train_generator.samples
print("Train dataset:", num_train_data)

validation_generator = train_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='validation')

num_val_data = validation_generator.samples
print("Validation dataset:", num_val_data)
# Out:
# Found 4031 images belonging to 55 classes.
# Train dataset: 4031
# Found 982 images belonging to 55 classes.
# Validation dataset: 982

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Adeg-Adeg
# 1 : Ba
# 2 : Bisah
# 3 : Ca
# 4 : Cecek
# 5 : Da
# 6 : Delapan
# 7 : Dua
# 8 : Empat
# 9 : Enam
# 10 : Ga
# 11 : Gantungan Ba
# 12 : Gantungan Ca
# 13 : Gantungan Da
# 14 : Gantungan Ga
# 15 : Gantungan Ha
# 16 : Gantungan Ja
# 17 : Gantungan Ka
# 18 : Gantungan La
# 19 : Gantungan Ma
# 20 : Gantungan Na
# 21 : Gantungan Nga
# 22 : Gantungan Nya
# 23 : Gantungan Pa
# 24 : Gantungan Ra
# 25 : Gantungan Sa
# 26 : Gantungan Ta
# 27 : Gantungan Wa
# 28 : Gantungan Ya
# 29 : Ha
# 30 : Ja
# 31 : Ka
# 32 : La
# 33 : Lima
# 34 : Ma
# 35 : Na
# 36 : Nga
# 37 : Nya
# 38 : Pa
# 39 : Pepet
# 40 : Ra
# 41 : Sa
# 42 : Satu
# 43 : Sembilan
# 44 : Suku
# 45 : Surang
# 46 : Ta
# 47 : Taleng
# 48 : Taleng Tedong
# 49 : Tedong
# 50 : Tiga
# 51 : Tujuh
# 52 : Ulu
# 53 : Wa
# 54 : Ya

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 15))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
model=tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(55, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.01))
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 148, 148, 16)      448
#
#  max_pooling2d_4 (MaxPooling  (None, 74, 74, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 15, 15, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_3 (Dense)             (None, 128)               401536
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 55)                7095
#
# =================================================================
# Total params: 485,655
# Trainable params: 485,655
# Non-trainable params: 0
# _________________________________________________________________

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs['accuracy'] >0.90 and logs['val_accuracy'] >0.90:
            print("\nThe process will stop because it has reached the target.")
            self.model.stop_training = True

callback = CustomCallback()

model.compile(
    loss=tf.keras.losses.CategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(0.001),
    metrics=['accuracy']
)


history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=200,
        batch_size=32,
        callbacks = [callback]
    )
# Out:
# Epoch 1/200
# 101/101 [==============================] - 9s 74ms/step - loss: 5.5001 - accuracy: 0.0437 - val_loss: 4.2184 - val_accuracy: 0.1589
# Epoch 2/200
# 101/101 [==============================] - 7s 70ms/step - loss: 3.6203 - accuracy: 0.2099 - val_loss: 2.5561 - val_accuracy: 0.5397
# Epoch 3/200
# 101/101 [==============================] - 7s 71ms/step - loss: 2.8185 - accuracy: 0.4217 - val_loss: 2.0241 - val_accuracy: 0.6721
# Epoch 4/200
# 101/101 [==============================] - 8s 83ms/step - loss: 2.3826 - accuracy: 0.5366 - val_loss: 1.6490 - val_accuracy: 0.7424
# Epoch 5/200
# 101/101 [==============================] - 8s 81ms/step - loss: 2.1435 - accuracy: 0.6108 - val_loss: 1.5981 - val_accuracy: 0.7281
# Epoch 6/200
# 101/101 [==============================] - 8s 77ms/step - loss: 2.0214 - accuracy: 0.6378 - val_loss: 1.5368 - val_accuracy: 0.7617
# Epoch 7/200
# 101/101 [==============================] - 8s 78ms/step - loss: 1.8884 - accuracy: 0.6656 - val_loss: 1.4578 - val_accuracy: 0.7719
# Epoch 8/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.7971 - accuracy: 0.6941 - val_loss: 1.3478 - val_accuracy: 0.7831
# Epoch 9/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.7084 - accuracy: 0.6993 - val_loss: 1.3632 - val_accuracy: 0.7862
# Epoch 10/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.6616 - accuracy: 0.7269 - val_loss: 1.3191 - val_accuracy: 0.7933
# Epoch 11/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.6072 - accuracy: 0.7298 - val_loss: 1.2806 - val_accuracy: 0.8126
# Epoch 12/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.5465 - accuracy: 0.7405 - val_loss: 1.2491 - val_accuracy: 0.8035
# Epoch 13/200
# 101/101 [==============================] - 8s 80ms/step - loss: 1.5101 - accuracy: 0.7547 - val_loss: 1.2963 - val_accuracy: 0.7739
# Epoch 14/200
# 101/101 [==============================] - 8s 81ms/step - loss: 1.5189 - accuracy: 0.7522 - val_loss: 1.1981 - val_accuracy: 0.8238
# Epoch 15/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.5017 - accuracy: 0.7527 - val_loss: 1.2658 - val_accuracy: 0.8147
# Epoch 16/200
# 101/101 [==============================] - 8s 79ms/step - loss: 1.4231 - accuracy: 0.7653 - val_loss: 1.2046 - val_accuracy: 0.8075
# Epoch 17/200
# 101/101 [==============================] - 8s 81ms/step - loss: 1.4052 - accuracy: 0.7760 - val_loss: 1.1734 - val_accuracy: 0.8218
# Epoch 18/200
# 101/101 [==============================] - 8s 75ms/step - loss: 1.4053 - accuracy: 0.7767 - val_loss: 1.2105 - val_accuracy: 0.8014
# Epoch 19/200
# 101/101 [==============================] - 7s 71ms/step - loss: 1.3756 - accuracy: 0.7852 - val_loss: 1.1981 - val_accuracy: 0.8116
# Epoch 20/200
# 101/101 [==============================] - 6s 62ms/step - loss: 1.3602 - accuracy: 0.7862 - val_loss: 1.1811 - val_accuracy: 0.8126
# Epoch 21/200
# 101/101 [==============================] - 6s 59ms/step - loss: 1.3170 - accuracy: 0.7973 - val_loss: 1.1948 - val_accuracy: 0.8004
# Epoch 22/200
# 101/101 [==============================] - 7s 68ms/step - loss: 1.3213 - accuracy: 0.7951 - val_loss: 1.1781 - val_accuracy: 0.8208
# Epoch 23/200
# 101/101 [==============================] - 8s 80ms/step - loss: 1.3384 - accuracy: 0.7958 - val_loss: 1.2551 - val_accuracy: 0.8136
# Epoch 24/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.3236 - accuracy: 0.7934 - val_loss: 1.1598 - val_accuracy: 0.8401
# Epoch 25/200
# 101/101 [==============================] - 8s 75ms/step - loss: 1.2783 - accuracy: 0.7978 - val_loss: 1.2333 - val_accuracy: 0.8269
# Epoch 26/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.3178 - accuracy: 0.7958 - val_loss: 1.1646 - val_accuracy: 0.8279
# Epoch 27/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.2717 - accuracy: 0.8100 - val_loss: 1.1746 - val_accuracy: 0.8248
# Epoch 28/200
# 101/101 [==============================] - 8s 75ms/step - loss: 1.2718 - accuracy: 0.8072 - val_loss: 1.1685 - val_accuracy: 0.8259
# Epoch 29/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.2342 - accuracy: 0.8152 - val_loss: 1.1266 - val_accuracy: 0.8360
# Epoch 30/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.2362 - accuracy: 0.8206 - val_loss: 1.1351 - val_accuracy: 0.8340
# Epoch 31/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.2300 - accuracy: 0.8182 - val_loss: 1.1394 - val_accuracy: 0.8248
# Epoch 32/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.2236 - accuracy: 0.8214 - val_loss: 1.1438 - val_accuracy: 0.8147
# Epoch 33/200
# 101/101 [==============================] - 8s 81ms/step - loss: 1.1883 - accuracy: 0.8271 - val_loss: 1.0938 - val_accuracy: 0.8248
# Epoch 34/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.2250 - accuracy: 0.8226 - val_loss: 1.1288 - val_accuracy: 0.8259
# Epoch 35/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.1862 - accuracy: 0.8338 - val_loss: 1.0754 - val_accuracy: 0.8462
# Epoch 36/200
# 101/101 [==============================] - 8s 78ms/step - loss: 1.2109 - accuracy: 0.8167 - val_loss: 1.1354 - val_accuracy: 0.8269
# Epoch 37/200
# 101/101 [==============================] - 8s 78ms/step - loss: 1.2197 - accuracy: 0.8219 - val_loss: 1.1255 - val_accuracy: 0.8269
# Epoch 38/200
# 101/101 [==============================] - 8s 78ms/step - loss: 1.1920 - accuracy: 0.8288 - val_loss: 1.1255 - val_accuracy: 0.8279
# Epoch 39/200
# 101/101 [==============================] - 8s 78ms/step - loss: 1.1886 - accuracy: 0.8291 - val_loss: 1.1332 - val_accuracy: 0.8289
# Epoch 40/200
# 101/101 [==============================] - 8s 78ms/step - loss: 1.1869 - accuracy: 0.8298 - val_loss: 1.1938 - val_accuracy: 0.8096
# Epoch 41/200
# 101/101 [==============================] - 8s 79ms/step - loss: 1.1634 - accuracy: 0.8410 - val_loss: 1.1699 - val_accuracy: 0.8126
# Epoch 42/200
# 101/101 [==============================] - 7s 74ms/step - loss: 1.1779 - accuracy: 0.8340 - val_loss: 1.1237 - val_accuracy: 0.8381
# Epoch 43/200
# 101/101 [==============================] - 8s 78ms/step - loss: 1.1373 - accuracy: 0.8452 - val_loss: 1.1175 - val_accuracy: 0.8259
# Epoch 44/200
# 101/101 [==============================] - 7s 71ms/step - loss: 1.1538 - accuracy: 0.8437 - val_loss: 1.1265 - val_accuracy: 0.8299
# Epoch 45/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1553 - accuracy: 0.8363 - val_loss: 1.2045 - val_accuracy: 0.8126
# Epoch 46/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1627 - accuracy: 0.8427 - val_loss: 1.1205 - val_accuracy: 0.8289
# Epoch 47/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1368 - accuracy: 0.8432 - val_loss: 1.1051 - val_accuracy: 0.8198
# Epoch 48/200
# 101/101 [==============================] - 7s 69ms/step - loss: 1.1468 - accuracy: 0.8405 - val_loss: 1.0568 - val_accuracy: 0.8350
# Epoch 49/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1013 - accuracy: 0.8512 - val_loss: 1.1777 - val_accuracy: 0.8126
# Epoch 50/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1322 - accuracy: 0.8375 - val_loss: 1.1537 - val_accuracy: 0.8187
# Epoch 51/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1341 - accuracy: 0.8502 - val_loss: 1.1373 - val_accuracy: 0.8269
# Epoch 52/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1061 - accuracy: 0.8459 - val_loss: 1.1067 - val_accuracy: 0.8218
# Epoch 53/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.1065 - accuracy: 0.8479 - val_loss: 1.1326 - val_accuracy: 0.8106
# Epoch 54/200
# 101/101 [==============================] - 7s 71ms/step - loss: 1.1020 - accuracy: 0.8509 - val_loss: 1.1854 - val_accuracy: 0.8055
# Epoch 55/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.0953 - accuracy: 0.8536 - val_loss: 1.0759 - val_accuracy: 0.8350
# Epoch 56/200
# 101/101 [==============================] - 7s 71ms/step - loss: 1.1083 - accuracy: 0.8514 - val_loss: 1.2244 - val_accuracy: 0.8086
# Epoch 57/200
# 101/101 [==============================] - 7s 72ms/step - loss: 1.1417 - accuracy: 0.8380 - val_loss: 1.1553 - val_accuracy: 0.8259
# Epoch 58/200
# 101/101 [==============================] - 8s 79ms/step - loss: 1.1104 - accuracy: 0.8526 - val_loss: 1.1092 - val_accuracy: 0.8269
# Epoch 59/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.0945 - accuracy: 0.8524 - val_loss: 1.1138 - val_accuracy: 0.8238
# Epoch 60/200
# 101/101 [==============================] - 7s 74ms/step - loss: 1.0814 - accuracy: 0.8556 - val_loss: 1.1347 - val_accuracy: 0.8391
# Epoch 61/200
# 101/101 [==============================] - 7s 66ms/step - loss: 1.1060 - accuracy: 0.8524 - val_loss: 1.1126 - val_accuracy: 0.8279
# Epoch 62/200
# 101/101 [==============================] - 6s 62ms/step - loss: 1.0784 - accuracy: 0.8546 - val_loss: 1.1538 - val_accuracy: 0.8208
# Epoch 63/200
# 101/101 [==============================] - 6s 63ms/step - loss: 1.0911 - accuracy: 0.8569 - val_loss: 1.1299 - val_accuracy: 0.8167
# Epoch 64/200
# 101/101 [==============================] - 7s 69ms/step - loss: 1.0797 - accuracy: 0.8569 - val_loss: 1.0933 - val_accuracy: 0.8360
# Epoch 65/200
# 101/101 [==============================] - 6s 62ms/step - loss: 1.0838 - accuracy: 0.8531 - val_loss: 1.0678 - val_accuracy: 0.8269
# Epoch 66/200
# 101/101 [==============================] - 6s 62ms/step - loss: 1.0812 - accuracy: 0.8544 - val_loss: 1.1142 - val_accuracy: 0.8350
# Epoch 67/200
# 101/101 [==============================] - 7s 73ms/step - loss: 1.0798 - accuracy: 0.8574 - val_loss: 1.0499 - val_accuracy: 0.8442
# Epoch 68/200
# 101/101 [==============================] - 6s 63ms/step - loss: 1.0817 - accuracy: 0.8601 - val_loss: 1.1381 - val_accuracy: 0.8259
# Epoch 69/200
# 101/101 [==============================] - 7s 65ms/step - loss: 1.0577 - accuracy: 0.8636 - val_loss: 1.1354 - val_accuracy: 0.8259
# Epoch 70/200
# 101/101 [==============================] - 6s 59ms/step - loss: 1.0200 - accuracy: 0.8712 - val_loss: 1.1415 - val_accuracy: 0.8391
# Epoch 71/200
# 101/101 [==============================] - 6s 61ms/step - loss: 1.0542 - accuracy: 0.8675 - val_loss: 1.1705 - val_accuracy: 0.8269
# Epoch 72/200
# 101/101 [==============================] - 6s 61ms/step - loss: 1.0574 - accuracy: 0.8708 - val_loss: 1.0402 - val_accuracy: 0.8259
# Epoch 73/200
# 101/101 [==============================] - 6s 63ms/step - loss: 1.0493 - accuracy: 0.8641 - val_loss: 1.1611 - val_accuracy: 0.8167
# Epoch 74/200
# 101/101 [==============================] - 6s 59ms/step - loss: 1.0624 - accuracy: 0.8616 - val_loss: 1.1756 - val_accuracy: 0.8269
# Epoch 75/200
# 101/101 [==============================] - 6s 60ms/step - loss: 1.0651 - accuracy: 0.8591 - val_loss: 1.1306 - val_accuracy: 0.8289
# Epoch 76/200
# 101/101 [==============================] - 6s 63ms/step - loss: 1.0517 - accuracy: 0.8668 - val_loss: 1.1022 - val_accuracy: 0.8350
# Epoch 77/200
# 101/101 [==============================] - 8s 80ms/step - loss: 1.0581 - accuracy: 0.8660 - val_loss: 1.0919 - val_accuracy: 0.8503
# Epoch 78/200
# 101/101 [==============================] - 7s 65ms/step - loss: 1.0423 - accuracy: 0.8705 - val_loss: 1.0861 - val_accuracy: 0.8310
# Epoch 79/200
# 101/101 [==============================] - 6s 62ms/step - loss: 1.0309 - accuracy: 0.8670 - val_loss: 1.1273 - val_accuracy: 0.8269
# Epoch 80/200
# 101/101 [==============================] - 14s 143ms/step - loss: 1.0666 - accuracy: 0.8675 - val_loss: 1.0876 - val_accuracy: 0.8422
# Epoch 81/200
# 101/101 [==============================] - 16s 158ms/step - loss: 1.0516 - accuracy: 0.8633 - val_loss: 1.1810 - val_accuracy: 0.8371
# Epoch 82/200
# 101/101 [==============================] - 16s 157ms/step - loss: 1.0644 - accuracy: 0.8683 - val_loss: 1.0880 - val_accuracy: 0.8320
# Epoch 83/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.0536 - accuracy: 0.8576 - val_loss: 1.1170 - val_accuracy: 0.8228
# Epoch 84/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.0397 - accuracy: 0.8710 - val_loss: 1.2247 - val_accuracy: 0.8177
# Epoch 85/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9957 - accuracy: 0.8814 - val_loss: 1.0978 - val_accuracy: 0.8401
# Epoch 86/200
# 101/101 [==============================] - 7s 71ms/step - loss: 1.0378 - accuracy: 0.8660 - val_loss: 1.1259 - val_accuracy: 0.8340
# Epoch 87/200
# 101/101 [==============================] - 7s 66ms/step - loss: 1.0598 - accuracy: 0.8591 - val_loss: 1.1234 - val_accuracy: 0.8371
# Epoch 88/200
# 101/101 [==============================] - 7s 67ms/step - loss: 1.0325 - accuracy: 0.8735 - val_loss: 1.1270 - val_accuracy: 0.8350
# Epoch 89/200
# 101/101 [==============================] - 7s 66ms/step - loss: 1.0221 - accuracy: 0.8678 - val_loss: 1.1389 - val_accuracy: 0.8279
# Epoch 90/200
# 101/101 [==============================] - 7s 67ms/step - loss: 1.0498 - accuracy: 0.8675 - val_loss: 1.1279 - val_accuracy: 0.8340
# Epoch 91/200
# 101/101 [==============================] - 7s 67ms/step - loss: 1.0242 - accuracy: 0.8774 - val_loss: 1.1133 - val_accuracy: 0.8360
# Epoch 92/200
# 101/101 [==============================] - 7s 66ms/step - loss: 1.0288 - accuracy: 0.8700 - val_loss: 1.1668 - val_accuracy: 0.8259
# Epoch 93/200
# 101/101 [==============================] - 7s 69ms/step - loss: 1.0376 - accuracy: 0.8730 - val_loss: 1.1364 - val_accuracy: 0.8269
# Epoch 94/200
# 101/101 [==============================] - 7s 71ms/step - loss: 1.0300 - accuracy: 0.8710 - val_loss: 1.1267 - val_accuracy: 0.8320
# Epoch 95/200
# 101/101 [==============================] - 8s 74ms/step - loss: 1.0175 - accuracy: 0.8822 - val_loss: 1.1034 - val_accuracy: 0.8350
# Epoch 96/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.0437 - accuracy: 0.8690 - val_loss: 1.1479 - val_accuracy: 0.8432
# Epoch 97/200
# 101/101 [==============================] - 7s 73ms/step - loss: 1.0311 - accuracy: 0.8722 - val_loss: 1.0847 - val_accuracy: 0.8360
# Epoch 98/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9800 - accuracy: 0.8886 - val_loss: 1.0597 - val_accuracy: 0.8330
# Epoch 99/200
# 101/101 [==============================] - 8s 76ms/step - loss: 1.0125 - accuracy: 0.8777 - val_loss: 1.0992 - val_accuracy: 0.8360
# Epoch 100/200
# 101/101 [==============================] - 8s 76ms/step - loss: 0.9923 - accuracy: 0.8846 - val_loss: 1.1484 - val_accuracy: 0.8350
# Epoch 101/200
# 101/101 [==============================] - 7s 73ms/step - loss: 1.0013 - accuracy: 0.8745 - val_loss: 1.0747 - val_accuracy: 0.8371
# Epoch 102/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9969 - accuracy: 0.8844 - val_loss: 1.0852 - val_accuracy: 0.8360
# Epoch 103/200
# 101/101 [==============================] - 7s 71ms/step - loss: 1.0278 - accuracy: 0.8621 - val_loss: 1.1072 - val_accuracy: 0.8422
# Epoch 104/200
# 101/101 [==============================] - 7s 72ms/step - loss: 1.0308 - accuracy: 0.8765 - val_loss: 1.1296 - val_accuracy: 0.8208
# Epoch 105/200
# 101/101 [==============================] - 7s 72ms/step - loss: 1.0073 - accuracy: 0.8789 - val_loss: 1.1237 - val_accuracy: 0.8269
# Epoch 106/200
# 101/101 [==============================] - 7s 73ms/step - loss: 0.9965 - accuracy: 0.8844 - val_loss: 1.1622 - val_accuracy: 0.8055
# Epoch 107/200
# 101/101 [==============================] - 7s 73ms/step - loss: 1.0086 - accuracy: 0.8752 - val_loss: 1.0967 - val_accuracy: 0.8462
# Epoch 108/200
# 101/101 [==============================] - 7s 73ms/step - loss: 0.9903 - accuracy: 0.8824 - val_loss: 1.0549 - val_accuracy: 0.8462
# Epoch 109/200
# 101/101 [==============================] - 7s 73ms/step - loss: 1.0157 - accuracy: 0.8695 - val_loss: 1.1156 - val_accuracy: 0.8391
# Epoch 110/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9983 - accuracy: 0.8732 - val_loss: 1.0401 - val_accuracy: 0.8513
# Epoch 111/200
# 101/101 [==============================] - 8s 74ms/step - loss: 0.9710 - accuracy: 0.8851 - val_loss: 1.0532 - val_accuracy: 0.8432
# Epoch 112/200
# 101/101 [==============================] - 7s 74ms/step - loss: 0.9781 - accuracy: 0.8809 - val_loss: 1.0988 - val_accuracy: 0.8381
# Epoch 113/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9547 - accuracy: 0.8906 - val_loss: 1.1652 - val_accuracy: 0.8177
# Epoch 114/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9949 - accuracy: 0.8819 - val_loss: 1.1218 - val_accuracy: 0.8381
# Epoch 115/200
# 101/101 [==============================] - 8s 77ms/step - loss: 1.0274 - accuracy: 0.8685 - val_loss: 1.0997 - val_accuracy: 0.8198
# Epoch 116/200
# 101/101 [==============================] - 8s 75ms/step - loss: 1.0150 - accuracy: 0.8792 - val_loss: 1.1479 - val_accuracy: 0.8340
# Epoch 117/200
# 101/101 [==============================] - 8s 77ms/step - loss: 0.9817 - accuracy: 0.8784 - val_loss: 1.0603 - val_accuracy: 0.8340
# Epoch 118/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9911 - accuracy: 0.8829 - val_loss: 1.0723 - val_accuracy: 0.8330
# Epoch 119/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9726 - accuracy: 0.8822 - val_loss: 1.0589 - val_accuracy: 0.8299
# Epoch 120/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9808 - accuracy: 0.8876 - val_loss: 1.1076 - val_accuracy: 0.8391
# Epoch 121/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9647 - accuracy: 0.8844 - val_loss: 1.0931 - val_accuracy: 0.8340
# Epoch 122/200
# 101/101 [==============================] - 7s 70ms/step - loss: 1.0092 - accuracy: 0.8765 - val_loss: 1.1312 - val_accuracy: 0.8330
# Epoch 123/200
# 101/101 [==============================] - 7s 69ms/step - loss: 1.0232 - accuracy: 0.8760 - val_loss: 1.1328 - val_accuracy: 0.8340
# Epoch 124/200
# 101/101 [==============================] - 7s 69ms/step - loss: 1.0058 - accuracy: 0.8837 - val_loss: 1.1211 - val_accuracy: 0.8473
# Epoch 125/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9975 - accuracy: 0.8834 - val_loss: 1.1410 - val_accuracy: 0.8330
# Epoch 126/200
# 101/101 [==============================] - 8s 74ms/step - loss: 0.9747 - accuracy: 0.8864 - val_loss: 1.0722 - val_accuracy: 0.8473
# Epoch 127/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9557 - accuracy: 0.8936 - val_loss: 1.1729 - val_accuracy: 0.8248
# Epoch 128/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9777 - accuracy: 0.8839 - val_loss: 1.1203 - val_accuracy: 0.8350
# Epoch 129/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9426 - accuracy: 0.8899 - val_loss: 1.0953 - val_accuracy: 0.8493
# Epoch 130/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9621 - accuracy: 0.8899 - val_loss: 1.1179 - val_accuracy: 0.8473
# Epoch 131/200
# 101/101 [==============================] - 7s 68ms/step - loss: 1.0004 - accuracy: 0.8765 - val_loss: 1.1207 - val_accuracy: 0.8381
# Epoch 132/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9817 - accuracy: 0.8856 - val_loss: 1.1393 - val_accuracy: 0.8391
# Epoch 133/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9633 - accuracy: 0.8886 - val_loss: 1.1109 - val_accuracy: 0.8411
# Epoch 134/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9918 - accuracy: 0.8819 - val_loss: 1.0999 - val_accuracy: 0.8452
# Epoch 135/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9528 - accuracy: 0.8918 - val_loss: 1.1421 - val_accuracy: 0.8340
# Epoch 136/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9670 - accuracy: 0.8856 - val_loss: 1.1085 - val_accuracy: 0.8360
# Epoch 137/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9613 - accuracy: 0.8906 - val_loss: 1.1884 - val_accuracy: 0.8310
# Epoch 138/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9595 - accuracy: 0.8899 - val_loss: 1.1305 - val_accuracy: 0.8360
# Epoch 139/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9533 - accuracy: 0.8921 - val_loss: 1.2366 - val_accuracy: 0.8187
# Epoch 140/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9575 - accuracy: 0.8913 - val_loss: 1.1091 - val_accuracy: 0.8330
# Epoch 141/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9594 - accuracy: 0.8871 - val_loss: 1.1315 - val_accuracy: 0.8218
# Epoch 142/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9548 - accuracy: 0.8990 - val_loss: 1.1498 - val_accuracy: 0.8371
# Epoch 143/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9794 - accuracy: 0.8856 - val_loss: 1.1604 - val_accuracy: 0.8340
# Epoch 144/200
# 101/101 [==============================] - 7s 73ms/step - loss: 0.9744 - accuracy: 0.8921 - val_loss: 1.1787 - val_accuracy: 0.8228
# Epoch 145/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9256 - accuracy: 0.8995 - val_loss: 1.1103 - val_accuracy: 0.8401
# Epoch 146/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9377 - accuracy: 0.8970 - val_loss: 1.1303 - val_accuracy: 0.8330
# Epoch 147/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9371 - accuracy: 0.8948 - val_loss: 1.1145 - val_accuracy: 0.8432
# Epoch 148/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9295 - accuracy: 0.8906 - val_loss: 1.1162 - val_accuracy: 0.8320
# Epoch 149/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9360 - accuracy: 0.8926 - val_loss: 1.1665 - val_accuracy: 0.8147
# Epoch 150/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9826 - accuracy: 0.8799 - val_loss: 1.0895 - val_accuracy: 0.8381
# Epoch 151/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9833 - accuracy: 0.8827 - val_loss: 1.1152 - val_accuracy: 0.8279
# Epoch 152/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9474 - accuracy: 0.8998 - val_loss: 1.1399 - val_accuracy: 0.8360
# Epoch 153/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9242 - accuracy: 0.8983 - val_loss: 1.0888 - val_accuracy: 0.8269
# Epoch 154/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9482 - accuracy: 0.8911 - val_loss: 1.1236 - val_accuracy: 0.8310
# Epoch 155/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9438 - accuracy: 0.8963 - val_loss: 1.1180 - val_accuracy: 0.8320
# Epoch 156/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9281 - accuracy: 0.8985 - val_loss: 1.1804 - val_accuracy: 0.8289
# Epoch 157/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9630 - accuracy: 0.8871 - val_loss: 1.0996 - val_accuracy: 0.8330
# Epoch 158/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9639 - accuracy: 0.8946 - val_loss: 1.1405 - val_accuracy: 0.8340
# Epoch 159/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9121 - accuracy: 0.9005 - val_loss: 1.1530 - val_accuracy: 0.8208
# Epoch 160/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9326 - accuracy: 0.8970 - val_loss: 1.2329 - val_accuracy: 0.8208
# Epoch 161/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9452 - accuracy: 0.9005 - val_loss: 1.1300 - val_accuracy: 0.8187
# Epoch 162/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9611 - accuracy: 0.8926 - val_loss: 1.1479 - val_accuracy: 0.8208
# Epoch 163/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9381 - accuracy: 0.9008 - val_loss: 1.1832 - val_accuracy: 0.8259
# Epoch 164/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9627 - accuracy: 0.8876 - val_loss: 1.0949 - val_accuracy: 0.8422
# Epoch 165/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9786 - accuracy: 0.8841 - val_loss: 1.1565 - val_accuracy: 0.8218
# Epoch 166/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9204 - accuracy: 0.9020 - val_loss: 1.1674 - val_accuracy: 0.8279
# Epoch 167/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9250 - accuracy: 0.9003 - val_loss: 1.1771 - val_accuracy: 0.8228
# Epoch 168/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9367 - accuracy: 0.8923 - val_loss: 1.1251 - val_accuracy: 0.8381
# Epoch 169/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.9139 - accuracy: 0.9003 - val_loss: 1.1518 - val_accuracy: 0.8350
# Epoch 170/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9675 - accuracy: 0.8869 - val_loss: 1.1675 - val_accuracy: 0.8310
# Epoch 171/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9403 - accuracy: 0.8968 - val_loss: 1.1731 - val_accuracy: 0.8340
# Epoch 172/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9254 - accuracy: 0.8988 - val_loss: 1.1314 - val_accuracy: 0.8381
# Epoch 173/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9469 - accuracy: 0.8928 - val_loss: 1.1678 - val_accuracy: 0.8136
# Epoch 174/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9072 - accuracy: 0.9067 - val_loss: 1.2183 - val_accuracy: 0.8259
# Epoch 175/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9361 - accuracy: 0.8941 - val_loss: 1.1524 - val_accuracy: 0.8310
# Epoch 176/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9292 - accuracy: 0.8998 - val_loss: 1.2006 - val_accuracy: 0.8381
# Epoch 177/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9258 - accuracy: 0.9032 - val_loss: 1.1651 - val_accuracy: 0.8238
# Epoch 178/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9278 - accuracy: 0.8990 - val_loss: 1.2329 - val_accuracy: 0.8269
# Epoch 179/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9309 - accuracy: 0.9025 - val_loss: 1.1663 - val_accuracy: 0.8248
# Epoch 180/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9155 - accuracy: 0.9015 - val_loss: 1.1607 - val_accuracy: 0.8310
# Epoch 181/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9052 - accuracy: 0.9003 - val_loss: 1.2103 - val_accuracy: 0.8208
# Epoch 182/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9334 - accuracy: 0.8963 - val_loss: 1.1672 - val_accuracy: 0.8442
# Epoch 183/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9124 - accuracy: 0.9025 - val_loss: 1.2366 - val_accuracy: 0.8238
# Epoch 184/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9105 - accuracy: 0.9035 - val_loss: 1.1738 - val_accuracy: 0.8350
# Epoch 185/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9139 - accuracy: 0.9042 - val_loss: 1.1279 - val_accuracy: 0.8279
# Epoch 186/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9216 - accuracy: 0.8988 - val_loss: 1.1442 - val_accuracy: 0.8269
# Epoch 187/200
# 101/101 [==============================] - 7s 68ms/step - loss: 0.8931 - accuracy: 0.9095 - val_loss: 1.2081 - val_accuracy: 0.8228
# Epoch 188/200
# 101/101 [==============================] - 7s 69ms/step - loss: 0.9021 - accuracy: 0.9035 - val_loss: 1.2120 - val_accuracy: 0.8350
# Epoch 189/200
# 101/101 [==============================] - 7s 70ms/step - loss: 0.9286 - accuracy: 0.8926 - val_loss: 1.1959 - val_accuracy: 0.8401
# Epoch 190/200
# 101/101 [==============================] - 7s 72ms/step - loss: 0.9115 - accuracy: 0.9018 - val_loss: 1.2141 - val_accuracy: 0.8310
# Epoch 191/200
# 101/101 [==============================] - 7s 73ms/step - loss: 0.9144 - accuracy: 0.8998 - val_loss: 1.2028 - val_accuracy: 0.8340
# Epoch 192/200
# 101/101 [==============================] - 7s 71ms/step - loss: 0.9129 - accuracy: 0.9080 - val_loss: 1.2376 - val_accuracy: 0.8218
# Epoch 193/200
# 101/101 [==============================] - 8s 77ms/step - loss: 0.9275 - accuracy: 0.9042 - val_loss: 1.1973 - val_accuracy: 0.8269
# Epoch 194/200
# 101/101 [==============================] - 8s 78ms/step - loss: 0.9410 - accuracy: 0.8926 - val_loss: 1.2013 - val_accuracy: 0.8248
# Epoch 195/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9339 - accuracy: 0.8966 - val_loss: 1.2257 - val_accuracy: 0.8086
# Epoch 196/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9088 - accuracy: 0.9072 - val_loss: 1.1492 - val_accuracy: 0.8198
# Epoch 197/200
# 101/101 [==============================] - 8s 74ms/step - loss: 0.8904 - accuracy: 0.9124 - val_loss: 1.2397 - val_accuracy: 0.8228
# Epoch 198/200
# 101/101 [==============================] - 8s 76ms/step - loss: 0.9207 - accuracy: 0.8973 - val_loss: 1.2063 - val_accuracy: 0.8310
# Epoch 199/200
# 101/101 [==============================] - 8s 75ms/step - loss: 0.9239 - accuracy: 0.8953 - val_loss: 1.1962 - val_accuracy: 0.8310
# Epoch 200/200
# 101/101 [==============================] - 7s 74ms/step - loss: 0.9125 - accuracy: 0.9080 - val_loss: 1.1971 - val_accuracy: 0.8136

# %%
# %matplotlib inline

import matplotlib.image as mping
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation loss')
plt.legend(loc = 'best')
plt.show()

# %%
model.save("D:/SELF/ML/aksara-detection/code/findingbali/hasil/aksarabali2.h5")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load the trained model
model = tf.keras.models.load_model("D:/SELF/ML/aksara-detection/code/findingbali/hasil/aksarabali2.h5")

# Generate predictions for the validation dataset
validation_generator.reset()
y_pred = model.predict(validation_generator, steps=len(validation_generator), verbose=1)
y_pred = np.argmax(y_pred, axis=1)

# Get the true labels for the validation dataset
y_true = validation_generator.classes

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=labels.values(), yticklabels=labels.values())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 31/31 [==============================] - 1s 20ms/step

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = tf.keras.models.load_model("D:/SELF/ML/aksara-detection/code/findingbali/hasil/aksarabali2.h5")

# Function to classify the input image
def classify_image(image_path):
    img = image.load_img(image_path, target_size=(150, 150))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0

    prediction = model.predict(img_array)
    class_index = np.argmax(prediction)
    confidence = prediction[0][class_index]

    return class_index, confidence

# Update the labels dictionary with class mappings
labels = {
    0: 'Adeg-Adeg',
    1: 'Ba',
    2: 'Bisah',
    3: 'Ca',
    4: 'Cecek',
    5: 'Da',
    6: 'Delapan',
    7: 'Dua',
    8: 'Empat',
    9: 'Enam',
    10: 'Ga',
    11: 'Gantungan Ba',
    12: 'Gantungan Ca',
    13: 'Gantungan Da',
    14: 'Gantungan Ga',
    15: 'Gantungan Ha',
    16: 'Gantungan Ja',
    17: 'Gantungan Ka',
    18: 'Gantungan La',
    19: 'Gantungan Ma',
    20: 'Gantungan Na',
    21: 'Gantungan Nga',
    22: 'Gantungan Nya',
    23: 'Gantungan Pa',
    24: 'Gantungan Ra',
    25: 'Gantungan Sa',
    26: 'Gantungan Ta',
    27: 'Gantungan Wa',
    28: 'Gantungan Ya',
    29: 'Ha',
    30: 'Ja',
    31: 'Ka',
    32: 'La',
    33: 'Lima',
    34: 'Ma',
    35: 'Na',
    36: 'Nga',
    37: 'Nya',
    38: 'Pa',
    39: 'Pepet',
    40: 'Ra',
    41: 'Sa',
    42: 'Satu',
    43: 'Sembilan',
    44: 'Suku',
    45: 'Surang',
    46: 'Ta',
    47: 'Taleng',
    48: 'Taleng Tedong',
    49: 'Tedong',
    50: 'Tiga',
    51: 'Tujuh',
    52: 'Ulu',
    53: 'Wa',
    54: 'Ya'
}

# %% [markdown]
# ### Checking Models

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Cecek.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 190ms/step
# The photo belongs to class 'Cecek' with confidence 0.29

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Da.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# The photo belongs to class 'Dua' with confidence 0.38

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Enam.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The photo belongs to class 'Enam' with confidence 0.67

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Gantungan Ka.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The photo belongs to class 'Dua' with confidence 0.69

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Gantungan Ta.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# The photo belongs to class 'Gantungan Ja' with confidence 0.41

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Gantungan Ya.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The photo belongs to class 'Gantungan Ya' with confidence 0.99

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Ka.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# The photo belongs to class 'Ka' with confidence 0.87

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Ma.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The photo belongs to class 'Dua' with confidence 0.56

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Na.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# The photo belongs to class 'Ka' with confidence 0.87

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Pepet.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The photo belongs to class 'Gantungan Ga' with confidence 0.77

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Suku.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The photo belongs to class 'Ya' with confidence 0.66

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Ta.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The photo belongs to class 'Ta' with confidence 0.24

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Ulu.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# The photo belongs to class 'Ga' with confidence 0.36

# %%
# Choose a photo and classify it
photo_path = "D:/SELF/ML/aksara-detection/code/findingbali/testing/Ya.jpg"
class_index, confidence = classify_image(photo_path)

# Get the label for the predicted class
predicted_class = labels[class_index]

print(f"The photo belongs to class '{predicted_class}' with confidence {confidence:.2f}")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# The photo belongs to class 'Ya' with confidence 0.99

# %% [markdown]
# ### Saving Models

# %%
model_json = model.to_json()
with open("aksarabali5.json", "w") as json_file:
    json_file.write(model_json)

model.save("D:/SELF/ML/aksara-detection/code/findingbali/hasil/aksarabali5.json")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: D:/SELF/ML/aksara-detection/code/findingbali/hasil/aksarabali5.json\assets
# INFO:tensorflow:Assets written to: D:/SELF/ML/aksara-detection/code/findingbali/hasil/aksarabali5.json\assets
